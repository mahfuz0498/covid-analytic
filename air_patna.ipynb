# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('/content/city_day.csv')

# %%
df.head()
# Out:
#         City        Date  PM2.5  PM10  ...  Toluene  Xylene  AQI  AQI_Bucket
# 0  Ahmedabad  2015-01-01    NaN   NaN  ...     0.02    0.00  NaN         NaN
# 1  Ahmedabad  2015-01-02    NaN   NaN  ...     5.50    3.77  NaN         NaN
# 2  Ahmedabad  2015-01-03    NaN   NaN  ...    16.40    2.25  NaN         NaN
# 3  Ahmedabad  2015-01-04    NaN   NaN  ...    10.14    1.00  NaN         NaN
# 4  Ahmedabad  2015-01-05    NaN   NaN  ...    18.89    2.78  NaN         NaN
#
# [5 rows x 16 columns]

# %%
#df['Date'] = pd.to_datetime(df['Date'])
df.tail()
# Out:
#                      City        Date  PM2.5  ...  Xylene   AQI    AQI_Bucket
# 26214  Thiruvananthapuram  2020-04-27  14.13  ...     NaN  63.0  Satisfactory
# 26215  Thiruvananthapuram  2020-04-28  23.84  ...     NaN  60.0  Satisfactory
# 26216  Thiruvananthapuram  2020-04-29  18.54  ...     NaN  57.0  Satisfactory
# 26217  Thiruvananthapuram  2020-04-30  20.57  ...     NaN  57.0  Satisfactory
# 26218  Thiruvananthapuram  2020-05-01  17.58  ...     NaN  82.0  Satisfactory
#
# [5 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4289
# PM10          10766
# NO             3233
# NO2            3217
# NOx            4043
# NH3            9847
# CO             1961
# SO2            3544
# O3             3660
# Benzene        5287
# Toluene        7555
# Xylene        16807
# AQI            4282
# AQI_Bucket     4282
# dtype: int64

# %%
df.shape
# Out:
# (26219, 16)

# %%
df.describe()
# Out:
#               PM2.5          PM10  ...       Xylene           AQI
# count  21930.000000  15453.000000  ...  9412.000000  21937.000000
# mean      71.828907    125.492380  ...     3.155895    175.840908
# std       67.161387     94.179918  ...     6.644018    146.143064
# min        0.040000      0.010000  ...     0.000000     13.000000
# 25%       31.450000     60.990000  ...     0.120000     85.000000
# 50%       52.220000    100.950000  ...     0.820000    124.000000
# 75%       85.655000    158.460000  ...     3.232500    226.000000
# max      949.990000   1000.000000  ...   170.370000   2049.000000
#
# [8 rows x 13 columns]

# %%
df['PM2.5'].fillna(df['PM2.5'].mean(), inplace= True)
df['NO'].fillna(df['NO'].mean(), inplace= True)
df['NO2'].fillna(df['NO2'].mean(), inplace= True)
df['NOx'].fillna(df['NOx'].mean(), inplace= True)
df['NH3'].fillna(df['NH3'].mean(), inplace= True)
df['CO'].fillna(df['CO'].mean(), inplace= True)
df['SO2'].fillna(df['SO2'].mean(), inplace= True)
df['O3'].fillna(df['O3'].mean(), inplace= True)
df['Benzene'].fillna(df['Benzene'].mean(), inplace= True)
df['Toluene'].fillna(df['Toluene'].mean(), inplace= True)
df['Xylene'].fillna(df['Xylene'].mean(), inplace= True)
df['AQI'].fillna(df['AQI'].mean(), inplace= True)

# %%
df  = df.drop(['AQI_Bucket','PM10'], axis = 1)

# %%
df.isnull().sum()
# Out:
# City       0
# Date       0
# PM2.5      0
# NO         0
# NO2        0
# NOx        0
# NH3        0
# CO         0
# SO2        0
# O3         0
# Benzene    0
# Toluene    0
# Xylene     0
# AQI        0
# dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.sort_index()

# %%
df.head()
# Out:
#         City       Date      PM2.5     NO  ...  Benzene  Toluene  Xylene         AQI
# 0  Ahmedabad 2015-01-01  71.828907   0.92  ...     0.00     0.02    0.00  175.840908
# 1  Ahmedabad 2015-01-02  71.828907   0.97  ...     3.68     5.50    3.77  175.840908
# 2  Ahmedabad 2015-01-03  71.828907  17.40  ...     6.80    16.40    2.25  175.840908
# 3  Ahmedabad 2015-01-04  71.828907   1.70  ...     4.43    10.14    1.00  175.840908
# 4  Ahmedabad 2015-01-05  71.828907  22.10  ...     7.01    18.89    2.78  175.840908
#
# [5 rows x 14 columns]

# %%
df['City'].value_counts()
# Out:
# Ahmedabad             1948
# Bengaluru             1948
# Delhi                 1948
# Chennai               1948
# Mumbai                1948
# Lucknow               1948
# Hyderabad             1945
# Patna                 1797
# Gurugram              1618
# Amritsar              1160
# Jorapokhar            1108
# Jaipur                1053
# Thiruvananthapuram    1051
# Amaravati              890
# Brajrajnagar           877
# Talcher                864
# Kolkata                753
# Guwahati               441
# Shillong               249
# Chandigarh             243
# Bhopal                 228
# Kochi                  101
# Ernakulam              101
# Aizawl                  52
# Name: City, dtype: int64

# %% [markdown]
# # Forecasting for patna

# %% [markdown]
# before corona

# %%
df_patna= df[df['City'] == 'Patna']
df_patna = df_patna.drop('City' , axis = 1)
df_patna.set_index('Date', inplace=True)

# %%
df_patna.shape
# Out:
# (1797, 12)

# %%
df_patna.head()
# Out:
#                 PM2.5     NO    NO2  ...  Toluene  Xylene         AQI
# Date                                 ...
# 2015-06-01  71.828907  14.41  25.06  ...     0.29    0.00  175.840908
# 2015-06-02  71.828907  25.00  22.48  ...     0.83    0.09  175.840908
# 2015-06-03  71.828907  14.29  17.16  ...     0.33    0.00  175.840908
# 2015-06-04  71.828907  13.03  15.62  ...     0.28    0.00  175.840908
# 2015-06-05  71.828907  10.40  10.36  ...     0.15    0.00  175.840908
#
# [5 rows x 12 columns]

# %%
df_patna_before_covid = df_patna.loc['2016-01-01' : '2020-03-23' ]
df_patna_after_covid = df_patna.loc['2020-03-24' : ]

# %%
df_patna_before_covid.head()
# Out:
#              PM2.5      NO    NO2     NOx  ...  Benzene  Toluene  Xylene    AQI
# Date                                       ...
# 2016-01-01  553.63  161.83  39.36  201.04  ...     0.88     2.61    2.34  619.0
# 2016-01-02  454.15  122.14  35.62  167.56  ...     0.73     2.00    1.67  598.0
# 2016-01-03  406.49   96.86  36.59  133.45  ...     0.71     2.15    1.79  522.0
# 2016-01-04  361.88  131.69  34.76  166.08  ...     0.66     1.93    1.63  501.0
# 2016-01-05  373.44  152.73  39.02  141.81  ...     0.71     2.07    1.78  490.0
#
# [5 rows x 12 columns]

# %%
df_patna_before_covid.shape
# Out:
# (1544, 12)

# %%
df_patna_before_covid=  df_patna_before_covid.resample('W').mean()

# %%
df_patna_before_covid.head()
# Out:
#                  PM2.5          NO        NO2  ...   Toluene    Xylene         AQI
# Date                                           ...
# 2016-01-03  471.423333  126.943333  37.190000  ...  2.253333  1.933333  579.666667
# 2016-01-10  298.560000  100.368571  38.722857  ...  1.614286  1.330000  449.714286
# 2016-01-17  286.038571   85.081429  37.647143  ...  1.535714  1.282857  426.714286
# 2016-01-24  212.845714   35.564286  32.221429  ...  0.981429  0.735714  364.285714
# 2016-01-31  306.870000   70.341429  38.250000  ...  1.282857  1.075714  440.857143
#
# [5 rows x 12 columns]

# %%
def plot_data(col):
    plt.figure(figsize=(17, 8))
    plt.plot(df_patna_before_covid[col])
    plt.xlabel('Time')
    plt.ylabel(col)
    plt.grid(False)
    plt.show()
    
for col in df_patna_before_covid.columns:
    plot_data(col)

# %%
df_patna_before_covid = df_patna_before_covid.reset_index()
df_patna_before_covid = df_patna_before_covid.rename({'Date':'ds','AQI':'y'} , axis = 1)
df_patna_before_covid.head(1)
# Out:
#           ds       PM2.5          NO  ...   Toluene    Xylene           y
# 0 2016-01-03  471.423333  126.943333  ...  2.253333  1.933333  579.666667
#
# [1 rows x 13 columns]

# %% [markdown]
# # Modeling on before dataset

# %%
train  = df_patna_before_covid

cols = train.columns.tolist()

# %%
cols = ['ds',
 'y', 
 'PM2.5',
 'NO',
 'NO2',
 'NOx',
 'NH3',
 'CO',
 'SO2',
 'O3',
 'Benzene',
 'Toluene',
 'Xylene'
 ]

# %%
train = train[cols]
train_y = train[['ds','y']]
train_y.head(3)
# Out:
#           ds           y
# 0 2016-01-03  579.666667
# 1 2016-01-10  449.714286
# 2 2016-01-17  426.714286

# %%
from fbprophet import Prophet
import logging

logging.getLogger().setLevel(logging.ERROR)

# %%
m = Prophet()

# %%
#m.add_regressor('PM2.5')
#m.add_regressor('NO')
#m.add_regressor('NO2')
#m.add_regressor('NOx')
#m.add_regressor('NH3')
#m.add_regressor('CO')
#m.add_regressor('SO2')
#m.add_regressor('O3')
#m.add_regressor('Benzene')
#m.add_regressor('Toluene')
#m.add_regressor('Xylene')

# %%
m.fit(train_y)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods= 365 )
forecast = m.predict(future)
forecast.tail()
# Out:
#             ds       trend  ...  multiplicative_terms_upper        yhat
# 582 2021-03-25  138.923322  ...                         0.0  131.560643
# 583 2021-03-26  138.814162  ...                         0.0  128.777593
# 584 2021-03-27  138.705003  ...                         0.0  125.871634
# 585 2021-03-28  138.595843  ...                         0.0  122.878650
# 586 2021-03-29  138.486684  ...                         0.0  119.836686
#
# [5 rows x 16 columns]

# %%
train_nox = train[['ds','NOx']]
train_nox = train_nox.rename({'NOx':'y'},axis=1)
m = Prophet()
m.fit(train_nox)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods= 365 )
forecast = m.predict(future)
forecast.tail()
# Out:
#             ds      trend  ...  multiplicative_terms_upper       yhat
# 582 2021-03-25  68.865082  ...                         0.0  60.144332
# 583 2021-03-26  68.922375  ...                         0.0  57.343051
# 584 2021-03-27  68.979668  ...                         0.0  54.663596
# 585 2021-03-28  69.036961  ...                         0.0  52.145603
# 586 2021-03-29  69.094254  ...                         0.0  49.825252
#
# [5 rows x 16 columns]

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)

# %%
def make_comparison_dataframe(historical, forecast):
    return forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))
cmp_df = make_comparison_dataframe(train_nox, forecast)

cmp_df.head()
# Out:
#                  yhat  yhat_lower  yhat_upper           y
# ds
# 2016-01-03  84.081813   56.747349  111.588069  167.350000
# 2016-01-10  86.945799   59.129156  113.712374  129.845714
# 2016-01-17  89.985114   61.239695  117.232319  122.070000
# 2016-01-24  93.969317   62.861407  122.464687   67.657143
# 2016-01-31  95.208703   67.206592  124.036524  108.597143

# %%
plt.figure(figsize=(17, 8))
plt.plot(cmp_df['yhat'])

plt.plot(cmp_df['y'])
plt.xlabel('Time')
plt.ylabel('Average Weekly NOx Concentration')
plt.grid(False)
plt.show()

# %% [markdown]
# # **During corona**

# %%
df_patna_after_covid.head()
# Out:
#             PM2.5     NO    NO2    NOx  ...  Benzene  Toluene  Xylene    AQI
# Date                                    ...
# 2020-03-24  65.94  69.45  48.75  80.41  ...     1.16     5.41    0.35  177.0
# 2020-03-25  73.42  52.49  47.99  66.72  ...     1.20     5.50    0.28  166.0
# 2020-03-26  58.01  51.67  46.63  65.41  ...     0.90     5.14    0.28  152.0
# 2020-03-27  58.25  51.61  45.25  64.28  ...     0.89     4.96    0.31  146.0
# 2020-03-28  31.87  47.07  43.29  59.88  ...     0.48     3.88    0.30  122.0
#
# [5 rows x 12 columns]

# %%
def plot_data(col):
    plt.figure(figsize=(17, 8))
    plt.plot(df_patna_after_covid[col])
    plt.xlabel('Time')
    plt.ylabel(col)
    plt.grid(False)
    plt.show()
    
for col in df_patna_after_covid.columns:
    plot_data(col)

# %%
df_patna_after_covid = df_patna_after_covid.reset_index()
df_patna_after_covid = df_patna_after_covid.rename({'Date':'ds','AQI':'y'} , axis = 1)
df_patna_after_covid.head(1)
# Out:
#           ds  PM2.5     NO    NO2  ...  Benzene  Toluene  Xylene      y
# 0 2020-03-24  65.94  69.45  48.75  ...     1.16     5.41    0.35  177.0
#
# [1 rows x 13 columns]

# %%
tr  = df_patna_after_covid

cols = tr.columns.tolist()

# %%
cols = ['ds',
 'y', 
 'PM2.5',
 'NO',
 'NO2',
 'NOx',
 'NH3',
 'CO',
 'SO2',
 'O3',
 'Benzene',
 'Toluene',
 'Xylene'
 ]

# %%
tr_nox = tr[['ds','NOx']]
tr_nox = tr_nox.rename({'NOx':'y'},axis=1)
f1 = Prophet()
f1.fit(tr_nox)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future1 = f1.make_future_dataframe(periods= 40 )
forecast1 = f1.predict(future1)
forecast1.tail()
# Out:
#            ds      trend  ...  multiplicative_terms_upper       yhat
# 74 2020-06-06  47.110594  ...                         0.0  43.820497
# 75 2020-06-07  46.982592  ...                         0.0  37.466247
# 76 2020-06-08  46.854591  ...                         0.0  39.215849
# 77 2020-06-09  46.726590  ...                         0.0  51.556856
# 78 2020-06-10  46.598589  ...                         0.0  55.633144
#
# [5 rows x 16 columns]

# %%
f1.plot_components(forecast1)

# %%
def make_comparison_dataframe(historical, forecast):
    return forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))
cmp_df1 = make_comparison_dataframe(tr_nox, forecast1)

cmp_df1.head()
# Out:
#                  yhat  yhat_lower  yhat_upper      y
# ds
# 2020-03-24  61.413260   48.259170   74.313096  80.41
# 2020-03-25  65.489536   53.372187   78.117013  66.72
# 2020-03-26  61.257499   48.304622   73.383845  65.41
# 2020-03-27  57.848789   45.068107   70.546612  64.28
# 2020-03-28  52.780848   41.009447   65.226390  59.88

# %%
plt.figure(figsize=(17, 8))
plt.plot(cmp_df1['yhat'])

plt.plot(cmp_df1['y'])
plt.xlabel('Time')
plt.ylabel('Average  NOx Concentration')
plt.grid(False)
plt.show()

# %% [markdown]
# **Now will do analysis for SO2 for before and after covid**

# %%
# before first

# %%
tr1_so2 = train[['ds','SO2']]
tr1_so2 = tr1_so2.rename({'SO2':'y'},axis=1)
s1 = Prophet()
s1.fit(tr1_so2)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future1_so2 = s1.make_future_dataframe(periods= 365 )
forecast1_so2 = s1.predict(future1_so2)
forecast1_so2.tail()
# Out:
#             ds      trend  ...  multiplicative_terms_upper       yhat
# 582 2021-03-25  29.805990  ...                         0.0  29.790464
# 583 2021-03-26  29.796274  ...                         0.0  30.249019
# 584 2021-03-27  29.786558  ...                         0.0  30.700115
# 585 2021-03-28  29.776842  ...                         0.0  31.138774
# 586 2021-03-29  29.767127  ...                         0.0  31.560471
#
# [5 rows x 16 columns]

# %%
s1.plot_components(forecast1_so2)

# %%
def make_comparison_dataframe(historical, forecast):
    return forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))
cmp_df1_so2 = make_comparison_dataframe(tr1_so2, forecast1_so2)

cmp_df1_so2.head()
# Out:
#                 yhat  yhat_lower  yhat_upper          y
# ds
# 2016-01-03 -2.842132  -16.849085   11.301340   5.480000
# 2016-01-10 -1.488239  -15.942109   12.573838   5.882857
# 2016-01-17 -0.228333  -15.133821   13.517422  12.228571
# 2016-01-24  0.217880  -13.311933   14.573593   5.534286
# 2016-01-31 -0.173066  -14.623834   14.319388   7.044286

# %%
plt.figure(figsize=(17, 8))
plt.plot(cmp_df1_so2['yhat'])

plt.plot(cmp_df1_so2['y'])
plt.xlabel('Time')
plt.ylabel('Average  so2 Concentration')
plt.grid(False)
plt.show()

# %%
# after covid

# %%
tr2_so2 = tr[['ds','SO2']]
tr2_so2 = tr_nox.rename({'SO2':'y'},axis=1)
s2 = Prophet()
s2.fit(tr2_so2)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future2_so2 = f1.make_future_dataframe(periods= 40 )
forecast2_so2 = f1.predict(future2_so2)
forecast2_so2.tail()
# Out:
#            ds      trend  ...  multiplicative_terms_upper       yhat
# 74 2020-06-06  47.110594  ...                         0.0  43.820497
# 75 2020-06-07  46.982592  ...                         0.0  37.466247
# 76 2020-06-08  46.854591  ...                         0.0  39.215849
# 77 2020-06-09  46.726590  ...                         0.0  51.556856
# 78 2020-06-10  46.598589  ...                         0.0  55.633144
#
# [5 rows x 16 columns]

# %%
s2.plot_components(forecast2_so2)

# %%
def make_comparison_dataframe(historical, forecast):
    return forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))
cmp_df2_so2 = make_comparison_dataframe(tr2_so2, forecast2_so2)

cmp_df2_so2.head()
# Out:
#                  yhat  yhat_lower  yhat_upper      y
# ds
# 2020-03-24  61.413260   49.692117   74.216439  80.41
# 2020-03-25  65.489536   51.811091   77.867802  66.72
# 2020-03-26  61.257499   49.329942   72.799423  65.41
# 2020-03-27  57.848789   45.107317   70.423232  64.28
# 2020-03-28  52.780848   40.811066   65.118198  59.88

# %%
plt.figure(figsize=(17, 8))
plt.plot(cmp_df2_so2['yhat'])

plt.plot(cmp_df2_so2['y'])
plt.xlabel('Time')
plt.ylabel('Average  so2 Concentration')
plt.grid(False)
plt.show()
