# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('/content/city_day.csv')

# %%
df.head()
# Out:
#         City        Date  PM2.5  PM10  ...  Toluene  Xylene  AQI  AQI_Bucket
# 0  Ahmedabad  2015-01-01    NaN   NaN  ...     0.02    0.00  NaN         NaN
# 1  Ahmedabad  2015-01-02    NaN   NaN  ...     5.50    3.77  NaN         NaN
# 2  Ahmedabad  2015-01-03    NaN   NaN  ...    16.40    2.25  NaN         NaN
# 3  Ahmedabad  2015-01-04    NaN   NaN  ...    10.14    1.00  NaN         NaN
# 4  Ahmedabad  2015-01-05    NaN   NaN  ...    18.89    2.78  NaN         NaN
#
# [5 rows x 16 columns]

# %%
#df['Date'] = pd.to_datetime(df['Date'])
df.tail()
# Out:
#                      City        Date  PM2.5  ...  Xylene   AQI    AQI_Bucket
# 26214  Thiruvananthapuram  2020-04-27  14.13  ...     NaN  63.0  Satisfactory
# 26215  Thiruvananthapuram  2020-04-28  23.84  ...     NaN  60.0  Satisfactory
# 26216  Thiruvananthapuram  2020-04-29  18.54  ...     NaN  57.0  Satisfactory
# 26217  Thiruvananthapuram  2020-04-30  20.57  ...     NaN  57.0  Satisfactory
# 26218  Thiruvananthapuram  2020-05-01  17.58  ...     NaN  82.0  Satisfactory
#
# [5 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4289
# PM10          10766
# NO             3233
# NO2            3217
# NOx            4043
# NH3            9847
# CO             1961
# SO2            3544
# O3             3660
# Benzene        5287
# Toluene        7555
# Xylene        16807
# AQI            4282
# AQI_Bucket     4282
# dtype: int64

# %%
df.shape
# Out:
# (26219, 16)

# %%
df.describe()
# Out:
#               PM2.5          PM10  ...       Xylene           AQI
# count  21930.000000  15453.000000  ...  9412.000000  21937.000000
# mean      71.828907    125.492380  ...     3.155895    175.840908
# std       67.161387     94.179918  ...     6.644018    146.143064
# min        0.040000      0.010000  ...     0.000000     13.000000
# 25%       31.450000     60.990000  ...     0.120000     85.000000
# 50%       52.220000    100.950000  ...     0.820000    124.000000
# 75%       85.655000    158.460000  ...     3.232500    226.000000
# max      949.990000   1000.000000  ...   170.370000   2049.000000
#
# [8 rows x 13 columns]

# %%
df['PM2.5'].fillna(df['PM2.5'].mean(), inplace= True)
df['NO'].fillna(df['NO'].mean(), inplace= True)
df['NO2'].fillna(df['NO2'].mean(), inplace= True)
df['NOx'].fillna(df['NOx'].mean(), inplace= True)
df['NH3'].fillna(df['NH3'].mean(), inplace= True)
df['CO'].fillna(df['CO'].mean(), inplace= True)
df['SO2'].fillna(df['SO2'].mean(), inplace= True)
df['O3'].fillna(df['O3'].mean(), inplace= True)
df['Benzene'].fillna(df['Benzene'].mean(), inplace= True)
df['Toluene'].fillna(df['Toluene'].mean(), inplace= True)
df['Xylene'].fillna(df['Xylene'].mean(), inplace= True)
df['AQI'].fillna(df['AQI'].mean(), inplace= True)

# %%
df  = df.drop(['AQI_Bucket','PM10'], axis = 1)

# %%
df.isnull().sum()
# Out:
# City       0
# Date       0
# PM2.5      0
# NO         0
# NO2        0
# NOx        0
# NH3        0
# CO         0
# SO2        0
# O3         0
# Benzene    0
# Toluene    0
# Xylene     0
# AQI        0
# dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.sort_index()

# %%
df.head()
# Out:
#         City       Date      PM2.5     NO  ...  Benzene  Toluene  Xylene         AQI
# 0  Ahmedabad 2015-01-01  71.828907   0.92  ...     0.00     0.02    0.00  175.840908
# 1  Ahmedabad 2015-01-02  71.828907   0.97  ...     3.68     5.50    3.77  175.840908
# 2  Ahmedabad 2015-01-03  71.828907  17.40  ...     6.80    16.40    2.25  175.840908
# 3  Ahmedabad 2015-01-04  71.828907   1.70  ...     4.43    10.14    1.00  175.840908
# 4  Ahmedabad 2015-01-05  71.828907  22.10  ...     7.01    18.89    2.78  175.840908
#
# [5 rows x 14 columns]

# %%
df['City'].value_counts()
# Out:
# Lucknow               1948
# Mumbai                1948
# Chennai               1948
# Delhi                 1948
# Bengaluru             1948
# Ahmedabad             1948
# Hyderabad             1945
# Patna                 1797
# Gurugram              1618
# Amritsar              1160
# Jorapokhar            1108
# Jaipur                1053
# Thiruvananthapuram    1051
# Amaravati              890
# Brajrajnagar           877
# Talcher                864
# Kolkata                753
# Guwahati               441
# Shillong               249
# Chandigarh             243
# Bhopal                 228
# Kochi                  101
# Ernakulam              101
# Aizawl                  52
# Name: City, dtype: int64

# %% [markdown]
# # Forecasting for Ahemdabad

# %% [markdown]
# before corona

# %%
df_mumbai = df[df['City'] == 'Mumbai']
df_mumbai = df_mumbai.drop('City' , axis = 1)
df_mumbai.set_index('Date', inplace=True)

# %%
df_mumbai.shape
# Out:
# (1948, 12)

# %%
df_mumbai.head()
# Out:
#                 PM2.5         NO        NO2  ...  Toluene  Xylene         AQI
# Date                                         ...
# 2015-01-01  71.828907  18.232528  29.009102  ...      0.0     0.0  175.840908
# 2015-01-02  71.828907  18.232528  29.009102  ...      0.0     0.0  175.840908
# 2015-01-03  71.828907  18.232528  29.009102  ...      0.0     0.0  175.840908
# 2015-01-04  71.828907  18.232528  29.009102  ...      0.0     0.0  175.840908
# 2015-01-05  71.828907  18.232528  29.009102  ...      0.0     0.0  175.840908
#
# [5 rows x 12 columns]

# %%
df_mumbai_before_covid = df_mumbai.loc['2016-01-01' : '2020-03-23' ]
df_mumbai_after_covid = df_mumbai.loc['2020-03-24' : ]

# %%
df_mumbai_before_covid.head()
# Out:
#                 PM2.5         NO        NO2  ...  Toluene  Xylene         AQI
# Date                                         ...
# 2016-01-01  71.828907  18.232528  29.009102  ...      0.0     0.0  175.840908
# 2016-01-02  71.828907  18.232528  29.009102  ...      0.0     0.0  175.840908
# 2016-01-03  71.828907  18.232528  29.009102  ...      0.0     0.0  175.840908
# 2016-01-04  71.828907  18.232528  29.009102  ...      0.0     0.0  175.840908
# 2016-01-05  71.828907  18.232528  29.009102  ...      0.0     0.0  175.840908
#
# [5 rows x 12 columns]

# %%
df_mumbai_before_covid.shape
# Out:
# (1544, 12)

# %%
df_mumbai_before_covid=  df_mumbai_before_covid.resample('W').mean()

# %%
df_mumbai_before_covid.head()
# Out:
#                 PM2.5         NO        NO2  ...  Toluene  Xylene         AQI
# Date                                         ...
# 2016-01-03  71.828907  18.232528  29.009102  ...      0.0     0.0  175.840908
# 2016-01-10  71.828907  18.232528  29.009102  ...      0.0     0.0  175.840908
# 2016-01-17  71.828907  18.232528  29.009102  ...      0.0     0.0  175.840908
# 2016-01-24  71.828907  18.232528  29.009102  ...      0.0     0.0  175.840908
# 2016-01-31  71.828907  18.232528  29.009102  ...      0.0     0.0  175.840908
#
# [5 rows x 12 columns]

# %%
def plot_data(col):
    plt.figure(figsize=(17, 8))
    plt.plot(df_mumbai_before_covid[col])
    plt.xlabel('Time')
    plt.ylabel(col)
    plt.grid(False)
    plt.show()
    
for col in df_mumbai_before_covid.columns:
    plot_data(col)

# %%
df_mumbai_before_covid = df_mumbai_before_covid.reset_index()
df_mumbai_before_covid = df_mumbai_before_covid.rename({'Date':'ds','AQI':'y'} , axis = 1)
df_mumbai_before_covid.head(1)
# Out:
#           ds      PM2.5         NO  ...  Toluene  Xylene           y
# 0 2016-01-03  71.828907  18.232528  ...      0.0     0.0  175.840908
#
# [1 rows x 13 columns]

# %% [markdown]
# # Modeling on before dataset

# %%
train  = df_mumbai_before_covid

cols = train.columns.tolist()

# %%
cols = ['ds',
 'y', 
 'PM2.5',
 'NO',
 'NO2',
 'NOx',
 'NH3',
 'CO',
 'SO2',
 'O3',
 'Benzene',
 'Toluene',
 'Xylene'
 ]

# %%
train = train[cols]
train_y = train[['ds','y']]
train_y.head(3)
# Out:
#           ds           y
# 0 2016-01-03  175.840908
# 1 2016-01-10  175.840908
# 2 2016-01-17  175.840908

# %%
from fbprophet import Prophet
import logging

logging.getLogger().setLevel(logging.ERROR)

# %%
m = Prophet()

# %%
#m.add_regressor('PM2.5')
#m.add_regressor('NO')
#m.add_regressor('NO2')
#m.add_regressor('NOx')
#m.add_regressor('NH3')
#m.add_regressor('CO')
#m.add_regressor('SO2')
#m.add_regressor('O3')
#m.add_regressor('Benzene')
#m.add_regressor('Toluene')
#m.add_regressor('Xylene')

# %%
m.fit(train_y)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods= 365 )
forecast = m.predict(future)
forecast.tail()
# Out:
#             ds      trend  ...  multiplicative_terms_upper       yhat
# 582 2021-03-25  72.373237  ...                         0.0  77.360157
# 583 2021-03-26  72.305870  ...                         0.0  76.675231
# 584 2021-03-27  72.238503  ...                         0.0  75.996518
# 585 2021-03-28  72.171135  ...                         0.0  75.334296
# 586 2021-03-29  72.103768  ...                         0.0  74.699360
#
# [5 rows x 16 columns]

# %%
train_nox = train[['ds','NOx']]
train_nox = train_nox.rename({'NOx':'y'},axis=1)
m = Prophet()
m.fit(train_nox)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods= 365 )
forecast = m.predict(future)
forecast.tail()
# Out:
#             ds      trend  ...  multiplicative_terms_upper       yhat
# 582 2021-03-25  60.915296  ...                         0.0  49.158419
# 583 2021-03-26  60.919209  ...                         0.0  48.929164
# 584 2021-03-27  60.923122  ...                         0.0  48.934233
# 585 2021-03-28  60.927035  ...                         0.0  49.164426
# 586 2021-03-29  60.930948  ...                         0.0  49.605662
#
# [5 rows x 16 columns]

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)

# %%
def make_comparison_dataframe(historical, forecast):
    return forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))
cmp_df = make_comparison_dataframe(train_nox, forecast)

cmp_df.head()
# Out:
#                  yhat  yhat_lower  yhat_upper          y
# ds
# 2016-01-03  62.312449   27.750465   94.365455  49.606667
# 2016-01-10  56.934227   24.942583   88.607601  22.128571
# 2016-01-17  48.181043   15.576135   80.179949  14.068571
# 2016-01-24  40.381870    9.752236   73.968893  34.840000
# 2016-01-31  35.400010    1.438319   68.310111  26.450000

# %%
plt.figure(figsize=(17, 8))
plt.plot(cmp_df['yhat'])

plt.plot(cmp_df['y'])
plt.xlabel('Time')
plt.ylabel('Average Weekly NOx Concentration')
plt.grid(False)
plt.show()

# %% [markdown]
# # **During corona**

# %%
df_mumbai_after_covid.head()
# Out:
#             PM2.5     NO    NO2    NOx  ...  Benzene   Toluene    Xylene   AQI
# Date                                    ...
# 2020-03-24  35.58  10.91  12.34  22.74  ...     4.72  9.029794  3.155895  86.0
# 2020-03-25  30.86  10.93  11.34  21.67  ...     5.05  9.029794  3.155895  91.0
# 2020-03-26  27.82  11.52  11.30  21.60  ...     6.40  9.029794  3.155895  71.0
# 2020-03-27  24.81   8.32   8.64  16.85  ...     3.78  9.029794  3.155895  70.0
# 2020-03-28  28.14   7.49  11.90  19.07  ...     3.96  9.029794  3.155895  78.0
#
# [5 rows x 12 columns]

# %%
def plot_data(col):
    plt.figure(figsize=(17, 8))
    plt.plot(df_mumbai_after_covid[col])
    plt.xlabel('Time')
    plt.ylabel(col)
    plt.grid(False)
    plt.show()
    
for col in df_mumbai_after_covid.columns:
    plot_data(col)

# %%
df_mumbai_after_covid = df_mumbai_after_covid.reset_index()
df_mumbai_after_covid = df_mumbai_after_covid.rename({'Date':'ds','AQI':'y'} , axis = 1)
df_mumbai_after_covid.head(1)
# Out:
#           ds  PM2.5     NO    NO2  ...  Benzene   Toluene    Xylene     y
# 0 2020-03-24  35.58  10.91  12.34  ...     4.72  9.029794  3.155895  86.0
#
# [1 rows x 13 columns]

# %%
tr  = df_mumbai_after_covid

cols = tr.columns.tolist()

# %%
cols = ['ds',
 'y', 
 'PM2.5',
 'NO',
 'NO2',
 'NOx',
 'NH3',
 'CO',
 'SO2',
 'O3',
 'Benzene',
 'Toluene',
 'Xylene'
 ]

# %%
tr_nox = tr[['ds','NOx']]
tr_nox = tr_nox.rename({'NOx':'y'},axis=1)
f1 = Prophet()
f1.fit(tr_nox)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future1 = f1.make_future_dataframe(periods= 40 )
forecast1 = f1.predict(future1)
forecast1.tail()
# Out:
#            ds      trend  ...  multiplicative_terms_upper       yhat
# 74 2020-06-06  28.912241  ...                         0.0  28.190417
# 75 2020-06-07  29.063723  ...                         0.0  28.880265
# 76 2020-06-08  29.215205  ...                         0.0  28.510099
# 77 2020-06-09  29.366687  ...                         0.0  29.880438
# 78 2020-06-10  29.518168  ...                         0.0  31.180341
#
# [5 rows x 16 columns]

# %%
f1.plot_components(forecast1)

# %%
def make_comparison_dataframe(historical, forecast):
    return forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))
cmp_df1 = make_comparison_dataframe(tr_nox, forecast1)

cmp_df1.head()
# Out:
#                  yhat  yhat_lower  yhat_upper      y
# ds
# 2020-03-24  18.220027   15.728537   20.710987  22.74
# 2020-03-25  19.519555   16.937614   22.242242  21.67
# 2020-03-26  18.567366   16.100220   21.045429  21.60
# 2020-03-27  17.035178   14.554840   19.593009  16.85
# 2020-03-28  17.588876   15.061407   20.255118  19.07

# %%
plt.figure(figsize=(17, 8))
plt.plot(cmp_df1['yhat'])

plt.plot(cmp_df1['y'])
plt.xlabel('Time')
plt.ylabel('Average  NOx Concentration')
plt.grid(False)
plt.show()

# %% [markdown]
# **Now will do analysis for SO2 for before and after covid**

# %%
# before first

# %%
tr1_so2 = train[['ds','SO2']]
tr1_so2 = tr1_so2.rename({'SO2':'y'},axis=1)
s1 = Prophet()
s1.fit(tr1_so2)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future1_so2 = s1.make_future_dataframe(periods= 365 )
forecast1_so2 = s1.predict(future1_so2)
forecast1_so2.tail()
# Out:
#             ds     trend  ...  multiplicative_terms_upper      yhat
# 582 2021-03-25  5.569256  ...                         0.0  5.647971
# 583 2021-03-26  5.555377  ...                         0.0  6.053080
# 584 2021-03-27  5.541499  ...                         0.0  6.455728
# 585 2021-03-28  5.527620  ...                         0.0  6.847577
# 586 2021-03-29  5.513741  ...                         0.0  7.220592
#
# [5 rows x 16 columns]

# %%
s1.plot_components(forecast1_so2)

# %%
def make_comparison_dataframe(historical, forecast):
    return forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))
cmp_df1_so2 = make_comparison_dataframe(tr1_so2, forecast1_so2)

cmp_df1_so2.head()
# Out:
#                  yhat  yhat_lower  yhat_upper          y
# ds
# 2016-01-03  14.472729    9.652025   19.064067  14.988734
# 2016-01-10  15.337693   10.924244   19.805124  14.988734
# 2016-01-17  15.924670   11.480301   20.391801  14.988734
# 2016-01-24  15.181896   10.430988   19.858017  14.988734
# 2016-01-31  13.762105    9.179707   18.134725  14.988734

# %%
plt.figure(figsize=(17, 8))
plt.plot(cmp_df1_so2['yhat'])

plt.plot(cmp_df1_so2['y'])
plt.xlabel('Time')
plt.ylabel('Average  so2 Concentration')
plt.grid(False)
plt.show()

# %%
# after covid

# %%
tr2_so2 = tr[['ds','SO2']]
tr2_so2 = tr_nox.rename({'SO2':'y'},axis=1)
s2 = Prophet()
s2.fit(tr2_so2)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future2_so2 = f1.make_future_dataframe(periods= 40 )
forecast2_so2 = f1.predict(future2_so2)
forecast2_so2.tail()
# Out:
#            ds      trend  ...  multiplicative_terms_upper       yhat
# 74 2020-06-06  28.912241  ...                         0.0  28.190417
# 75 2020-06-07  29.063723  ...                         0.0  28.880265
# 76 2020-06-08  29.215205  ...                         0.0  28.510099
# 77 2020-06-09  29.366687  ...                         0.0  29.880438
# 78 2020-06-10  29.518168  ...                         0.0  31.180341
#
# [5 rows x 16 columns]

# %%
s2.plot_components(forecast2_so2)

# %%
def make_comparison_dataframe(historical, forecast):
    return forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))
cmp_df2_so2 = make_comparison_dataframe(tr2_so2, forecast2_so2)

cmp_df2_so2.head()
# Out:
#                  yhat  yhat_lower  yhat_upper      y
# ds
# 2020-03-24  18.220027   15.634794   20.786451  22.74
# 2020-03-25  19.519555   17.054010   22.167176  21.67
# 2020-03-26  18.567366   16.218330   21.240703  21.60
# 2020-03-27  17.035178   14.576716   19.674538  16.85
# 2020-03-28  17.588876   15.048706   20.188929  19.07

# %%
plt.figure(figsize=(17, 8))
plt.plot(cmp_df2_so2['yhat'])

plt.plot(cmp_df2_so2['y'])
plt.xlabel('Time')
plt.ylabel('Average  so2 Concentration')
plt.grid(False)
plt.show()
