# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('/content/city_day.csv')

# %%
df.head()
# Out:
#         City        Date  PM2.5  PM10  ...  Toluene  Xylene  AQI  AQI_Bucket
# 0  Ahmedabad  2015-01-01    NaN   NaN  ...     0.02    0.00  NaN         NaN
# 1  Ahmedabad  2015-01-02    NaN   NaN  ...     5.50    3.77  NaN         NaN
# 2  Ahmedabad  2015-01-03    NaN   NaN  ...    16.40    2.25  NaN         NaN
# 3  Ahmedabad  2015-01-04    NaN   NaN  ...    10.14    1.00  NaN         NaN
# 4  Ahmedabad  2015-01-05    NaN   NaN  ...    18.89    2.78  NaN         NaN
#
# [5 rows x 16 columns]

# %%
#df['Date'] = pd.to_datetime(df['Date'])
df.tail()
# Out:
#                      City        Date  PM2.5  ...  Xylene   AQI    AQI_Bucket
# 26214  Thiruvananthapuram  2020-04-27  14.13  ...     NaN  63.0  Satisfactory
# 26215  Thiruvananthapuram  2020-04-28  23.84  ...     NaN  60.0  Satisfactory
# 26216  Thiruvananthapuram  2020-04-29  18.54  ...     NaN  57.0  Satisfactory
# 26217  Thiruvananthapuram  2020-04-30  20.57  ...     NaN  57.0  Satisfactory
# 26218  Thiruvananthapuram  2020-05-01  17.58  ...     NaN  82.0  Satisfactory
#
# [5 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4289
# PM10          10766
# NO             3233
# NO2            3217
# NOx            4043
# NH3            9847
# CO             1961
# SO2            3544
# O3             3660
# Benzene        5287
# Toluene        7555
# Xylene        16807
# AQI            4282
# AQI_Bucket     4282
# dtype: int64

# %%
df.shape
# Out:
# (26219, 16)

# %%
df.describe()
# Out:
#               PM2.5          PM10  ...       Xylene           AQI
# count  21930.000000  15453.000000  ...  9412.000000  21937.000000
# mean      71.828907    125.492380  ...     3.155895    175.840908
# std       67.161387     94.179918  ...     6.644018    146.143064
# min        0.040000      0.010000  ...     0.000000     13.000000
# 25%       31.450000     60.990000  ...     0.120000     85.000000
# 50%       52.220000    100.950000  ...     0.820000    124.000000
# 75%       85.655000    158.460000  ...     3.232500    226.000000
# max      949.990000   1000.000000  ...   170.370000   2049.000000
#
# [8 rows x 13 columns]

# %%
df['PM2.5'].fillna(df['PM2.5'].mean(), inplace= True)
df['NO'].fillna(df['NO'].mean(), inplace= True)
df['NO2'].fillna(df['NO2'].mean(), inplace= True)
df['NOx'].fillna(df['NOx'].mean(), inplace= True)
df['NH3'].fillna(df['NH3'].mean(), inplace= True)
df['CO'].fillna(df['CO'].mean(), inplace= True)
df['SO2'].fillna(df['SO2'].mean(), inplace= True)
df['O3'].fillna(df['O3'].mean(), inplace= True)
df['Benzene'].fillna(df['Benzene'].mean(), inplace= True)
df['Toluene'].fillna(df['Toluene'].mean(), inplace= True)
df['Xylene'].fillna(df['Xylene'].mean(), inplace= True)
df['AQI'].fillna(df['AQI'].mean(), inplace= True)

# %%
df  = df.drop(['AQI_Bucket','PM10'], axis = 1)

# %%
df.isnull().sum()
# Out:
# City       0
# Date       0
# PM2.5      0
# NO         0
# NO2        0
# NOx        0
# NH3        0
# CO         0
# SO2        0
# O3         0
# Benzene    0
# Toluene    0
# Xylene     0
# AQI        0
# dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.sort_index()

# %%
df.head()
# Out:
#         City       Date      PM2.5     NO  ...  Benzene  Toluene  Xylene         AQI
# 0  Ahmedabad 2015-01-01  71.828907   0.92  ...     0.00     0.02    0.00  175.840908
# 1  Ahmedabad 2015-01-02  71.828907   0.97  ...     3.68     5.50    3.77  175.840908
# 2  Ahmedabad 2015-01-03  71.828907  17.40  ...     6.80    16.40    2.25  175.840908
# 3  Ahmedabad 2015-01-04  71.828907   1.70  ...     4.43    10.14    1.00  175.840908
# 4  Ahmedabad 2015-01-05  71.828907  22.10  ...     7.01    18.89    2.78  175.840908
#
# [5 rows x 14 columns]

# %%
df['City'].value_counts()
# Out:
# Ahmedabad             1948
# Mumbai                1948
# Chennai               1948
# Lucknow               1948
# Bengaluru             1948
# Delhi                 1948
# Hyderabad             1945
# Patna                 1797
# Gurugram              1618
# Amritsar              1160
# Jorapokhar            1108
# Jaipur                1053
# Thiruvananthapuram    1051
# Amaravati              890
# Brajrajnagar           877
# Talcher                864
# Kolkata                753
# Guwahati               441
# Shillong               249
# Chandigarh             243
# Bhopal                 228
# Ernakulam              101
# Kochi                  101
# Aizawl                  52
# Name: City, dtype: int64

# %% [markdown]
# # Forecasting for Ahemdabad

# %% [markdown]
# before corona

# %%
df_ahmed = df[df['City'] == 'Ahmedabad']
df_ahmed = df_ahmed.drop('City' , axis = 1)
df_ahmed.set_index('Date', inplace=True)

# %%
df_ahmed.shape
# Out:
# (1948, 12)

# %%
df_ahmed.head()
# Out:
#                 PM2.5     NO    NO2  ...  Toluene  Xylene         AQI
# Date                                 ...
# 2015-01-01  71.828907   0.92  18.22  ...     0.02    0.00  175.840908
# 2015-01-02  71.828907   0.97  15.69  ...     5.50    3.77  175.840908
# 2015-01-03  71.828907  17.40  19.30  ...    16.40    2.25  175.840908
# 2015-01-04  71.828907   1.70  18.48  ...    10.14    1.00  175.840908
# 2015-01-05  71.828907  22.10  21.42  ...    18.89    2.78  175.840908
#
# [5 rows x 12 columns]

# %%
df_ahmed_before_covid = df_ahmed.loc['2016-01-01' : '2020-03-23' ]
df_ahmed_after_covid = df_ahmed.loc['2020-03-24' : ]

# %%
df_ahmed_before_covid.head()
# Out:
#                 PM2.5         NO        NO2  ...   Toluene    Xylene         AQI
# Date                                         ...
# 2016-01-01  71.828907  18.232528  29.009102  ...  9.029794  3.155895  175.840908
# 2016-01-02  71.828907  18.232528  29.009102  ...  9.029794  3.155895  175.840908
# 2016-01-03  71.828907  18.232528  29.009102  ...  9.029794  3.155895  175.840908
# 2016-01-04  71.828907  18.232528  29.009102  ...  9.029794  3.155895  175.840908
# 2016-01-05  71.828907  18.232528  29.009102  ...  9.029794  3.155895  175.840908
#
# [5 rows x 12 columns]

# %%
df_ahmed_before_covid.shape
# Out:
# (1544, 12)

# %%
df_ahmed_before_covid=  df_ahmed_before_covid.resample('W').mean()

# %%
df_ahmed_before_covid.head()
# Out:
#                 PM2.5         NO        NO2  ...   Toluene    Xylene         AQI
# Date                                         ...
# 2016-01-03  71.828907  18.232528  29.009102  ...  9.029794  3.155895  175.840908
# 2016-01-10  71.828907  18.232528  29.009102  ...  9.029794  3.155895  175.840908
# 2016-01-17  71.828907  18.232528  29.009102  ...  9.029794  3.155895  175.840908
# 2016-01-24  71.828907  18.232528  29.009102  ...  9.029794  3.155895  175.840908
# 2016-01-31  71.828907  18.232528  29.009102  ...  9.029794  3.155895  175.840908
#
# [5 rows x 12 columns]

# %%
def plot_data(col):
    plt.figure(figsize=(17, 8))
    plt.plot(df_ahmed_before_covid[col])
    plt.xlabel('Time')
    plt.ylabel(col)
    plt.grid(False)
    plt.show()
    
for col in df_ahmed_before_covid.columns:
    plot_data(col)

# %%
df_ahmed_before_covid = df_ahmed_before_covid.reset_index()
df_ahmed_before_covid = df_ahmed_before_covid.rename({'Date':'ds','AQI':'y'} , axis = 1)
df_ahmed_before_covid.head(1)
# Out:
#           ds      PM2.5         NO  ...   Toluene    Xylene           y
# 0 2016-01-03  71.828907  18.232528  ...  9.029794  3.155895  175.840908
#
# [1 rows x 13 columns]

# %% [markdown]
# # Modeling on before dataset

# %%
train  = df_ahmed_before_covid

cols = train.columns.tolist()

# %%
cols = ['ds',
 'y', 
 'PM2.5',
 'NO',
 'NO2',
 'NOx',
 'NH3',
 'CO',
 'SO2',
 'O3',
 'Benzene',
 'Toluene',
 'Xylene'
 ]

# %%
train = train[cols]
train_y = train[['ds','y']]
train_y.head(3)
# Out:
#           ds           y
# 0 2016-01-03  175.840908
# 1 2016-01-10  175.840908
# 2 2016-01-17  175.840908

# %%
from fbprophet import Prophet
import logging

logging.getLogger().setLevel(logging.ERROR)

# %%
m = Prophet()

# %%
#m.add_regressor('PM2.5')
#m.add_regressor('NO')
#m.add_regressor('NO2')
#m.add_regressor('NOx')
#m.add_regressor('NH3')
#m.add_regressor('CO')
#m.add_regressor('SO2')
#m.add_regressor('O3')
#m.add_regressor('Benzene')
#m.add_regressor('Toluene')
#m.add_regressor('Xylene')

# %%
m.fit(train_y)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods= 365 )
forecast = m.predict(future)
forecast.tail()
# Out:
#             ds       trend  ...  multiplicative_terms_upper        yhat
# 582 2021-03-25  283.729951  ...                         0.0  325.056644
# 583 2021-03-26  283.388957  ...                         0.0  324.675181
# 584 2021-03-27  283.047964  ...                         0.0  324.331350
# 585 2021-03-28  282.706971  ...                         0.0  324.021888
# 586 2021-03-29  282.365978  ...                         0.0  323.740600
#
# [5 rows x 16 columns]

# %%
train_nox = train[['ds','NOx']]
train_nox = train_nox.rename({'NOx':'y'},axis=1)
m = Prophet()
m.fit(train_nox)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods= 365 )
forecast = m.predict(future)
forecast.tail()
# Out:
#             ds      trend  ...  multiplicative_terms_upper       yhat
# 582 2021-03-25  68.474099  ...                         0.0  61.926131
# 583 2021-03-26  68.491576  ...                         0.0  62.182865
# 584 2021-03-27  68.509054  ...                         0.0  62.518138
# 585 2021-03-28  68.526531  ...                         0.0  62.926843
# 586 2021-03-29  68.544009  ...                         0.0  63.401993
#
# [5 rows x 16 columns]

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)

# %%
def make_comparison_dataframe(historical, forecast):
    return forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))
cmp_df = make_comparison_dataframe(train_nox, forecast)

cmp_df.head()
# Out:
#                  yhat  yhat_lower  yhat_upper          y
# ds
# 2016-01-03  25.775060   -3.558844   54.236527  33.657667
# 2016-01-10  27.621424    1.559728   57.036426  33.657667
# 2016-01-17  28.007368    0.136581   58.153623  33.657667
# 2016-01-24  30.345900    0.397576   62.753168  33.657667
# 2016-01-31  34.506454    5.338346   64.030674  33.657667

# %%
plt.figure(figsize=(17, 8))
plt.plot(cmp_df['yhat'])

plt.plot(cmp_df['y'])
plt.xlabel('Time')
plt.ylabel('Average Weekly NOx Concentration')
plt.grid(False)
plt.show()

# %% [markdown]
# # **During corona**

# %%
df_ahmed_after_covid.head()
# Out:
#             PM2.5    NO    NO2    NOx  ...  Benzene  Toluene  Xylene    AQI
# Date                                   ...
# 2020-03-24  31.89  2.96  25.20  14.50  ...     4.01    23.25    3.33  135.0
# 2020-03-25  33.25  4.28  33.45  19.44  ...     4.90    18.98    2.85  195.0
# 2020-03-26  43.67  7.11  26.61  17.61  ...     4.71    19.16    2.80  216.0
# 2020-03-27  22.93  5.23  18.52  12.87  ...     1.58     7.50    1.08  193.0
# 2020-03-28  37.73  4.67  35.52  20.77  ...     6.37    26.05    3.56  160.0
#
# [5 rows x 12 columns]

# %%
def plot_data(col):
    plt.figure(figsize=(17, 8))
    plt.plot(df_ahmed_after_covid[col])
    plt.xlabel('Time')
    plt.ylabel(col)
    plt.grid(False)
    plt.show()
    
for col in df_ahmed_after_covid.columns:
    plot_data(col)

# %%
df_ahmed_after_covid = df_ahmed_after_covid.reset_index()
df_ahmed_after_covid = df_ahmed_after_covid.rename({'Date':'ds','AQI':'y'} , axis = 1)
df_ahmed_after_covid.head(1)
# Out:
#           ds  PM2.5    NO   NO2   NOx  ...     O3  Benzene  Toluene  Xylene      y
# 0 2020-03-24  31.89  2.96  25.2  14.5  ...  47.99     4.01    23.25    3.33  135.0
#
# [1 rows x 13 columns]

# %%
tr  = df_ahmed_after_covid

cols = tr.columns.tolist()

# %%
cols = ['ds',
 'y', 
 'PM2.5',
 'NO',
 'NO2',
 'NOx',
 'NH3',
 'CO',
 'SO2',
 'O3',
 'Benzene',
 'Toluene',
 'Xylene'
 ]

# %%
tr_nox = tr[['ds','NOx']]
tr_nox = tr_nox.rename({'NOx':'y'},axis=1)
f1 = Prophet()
f1.fit(tr_nox)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future1 = f1.make_future_dataframe(periods= 40 )
forecast1 = f1.predict(future1)
forecast1.tail()
# Out:
#            ds     trend  ...  multiplicative_terms_upper      yhat
# 74 2020-06-06  2.029984  ...                         0.0  4.225469
# 75 2020-06-07  1.804517  ...                         0.0  1.919486
# 76 2020-06-08  1.579049  ...                         0.0  2.457479
# 77 2020-06-09  1.353581  ...                         0.0 -0.333919
# 78 2020-06-10  1.128113  ...                         0.0  0.014411
#
# [5 rows x 16 columns]

# %%
f1.plot_components(forecast1)

# %%
def make_comparison_dataframe(historical, forecast):
    return forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))
cmp_df1 = make_comparison_dataframe(tr_nox, forecast1)

cmp_df1.head()
# Out:
#                  yhat  yhat_lower  yhat_upper      y
# ds
# 2020-03-24  17.027099   13.227469   20.558344  14.50
# 2020-03-25  17.375428   13.584485   20.927563  19.44
# 2020-03-26  17.783757   14.136136   21.371051  17.61
# 2020-03-27  18.130419   14.345534   21.858519  12.87
# 2020-03-28  20.008212   16.376162   23.619352  20.77

# %%
plt.figure(figsize=(17, 8))
plt.plot(cmp_df1['yhat'])

plt.plot(cmp_df1['y'])
plt.xlabel('Time')
plt.ylabel('Average  NOx Concentration')
plt.grid(False)
plt.show()

# %% [markdown]
# **Now will do analysis for SO2 for before and after covid**

# %%
# before first

# %%
tr1_so2 = train[['ds','SO2']]
tr1_so2 = tr1_so2.rename({'SO2':'y'},axis=1)
s1 = Prophet()
s1.fit(tr1_so2)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future1_so2 = s1.make_future_dataframe(periods= 365 )
forecast1_so2 = s1.predict(future1_so2)
forecast1_so2.tail()
# Out:
#             ds      trend  ...  multiplicative_terms_upper       yhat
# 582 2021-03-25  94.720432  ...                         0.0  86.538537
# 583 2021-03-26  94.760675  ...                         0.0  86.159569
# 584 2021-03-27  94.800917  ...                         0.0  85.801896
# 585 2021-03-28  94.841160  ...                         0.0  85.468966
# 586 2021-03-29  94.881402  ...                         0.0  85.163593
#
# [5 rows x 16 columns]

# %%
s1.plot_components(forecast1_so2)

# %%
def make_comparison_dataframe(historical, forecast):
    return forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))
cmp_df1_so2 = make_comparison_dataframe(tr1_so2, forecast1_so2)

cmp_df1_so2.head()
# Out:
#                  yhat  yhat_lower  yhat_upper          y
# ds
# 2016-01-03  14.514050  -18.644401   49.754378  14.988734
# 2016-01-10  14.757045  -21.687078   48.817447  14.988734
# 2016-01-17  15.569356  -19.749736   49.503167  14.988734
# 2016-01-24  18.259836  -16.983963   52.520714  14.988734
# 2016-01-31  21.151780  -13.707458   54.247546  14.988734

# %%
plt.figure(figsize=(17, 8))
plt.plot(cmp_df1_so2['yhat'])

plt.plot(cmp_df1_so2['y'])
plt.xlabel('Time')
plt.ylabel('Average  so2 Concentration')
plt.grid(False)
plt.show()

# %%
# after covid

# %%
tr2_so2 = tr[['ds','SO2']]
tr2_so2 = tr_nox.rename({'SO2':'y'},axis=1)
s2 = Prophet()
s2.fit(tr2_so2)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future2_so2 = f1.make_future_dataframe(periods= 40 )
forecast2_so2 = f1.predict(future2_so2)
forecast2_so2.tail()
# Out:
#            ds     trend  ...  multiplicative_terms_upper      yhat
# 74 2020-06-06  2.029984  ...                         0.0  4.225469
# 75 2020-06-07  1.804517  ...                         0.0  1.919486
# 76 2020-06-08  1.579049  ...                         0.0  2.457479
# 77 2020-06-09  1.353581  ...                         0.0 -0.333919
# 78 2020-06-10  1.128113  ...                         0.0  0.014411
#
# [5 rows x 16 columns]

# %%
s2.plot_components(forecast2_so2)

# %%
def make_comparison_dataframe(historical, forecast):
    return forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']].join(historical.set_index('ds'))
cmp_df2_so2 = make_comparison_dataframe(tr2_so2, forecast2_so2)

cmp_df2_so2.head()
# Out:
#                  yhat  yhat_lower  yhat_upper      y
# ds
# 2020-03-24  17.027099   13.090688   20.793840  14.50
# 2020-03-25  17.375428   13.679718   21.128737  19.44
# 2020-03-26  17.783757   14.019395   21.778622  17.61
# 2020-03-27  18.130419   14.574981   21.582243  12.87
# 2020-03-28  20.008212   16.572643   23.549106  20.77

# %%
plt.figure(figsize=(17, 8))
plt.plot(cmp_df2_so2['yhat'])

plt.plot(cmp_df2_so2['y'])
plt.xlabel('Time')
plt.ylabel('Average  so2 Concentration')
plt.grid(False)
plt.show()
